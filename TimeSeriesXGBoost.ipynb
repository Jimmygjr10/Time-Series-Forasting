# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import xgboost as xgb
from sklearn.metrics import mean_squared_error

color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')

# %% [markdown]
# ## Read in Excel File

# %%
df = pd.read_excel('PJMW_hourly.xlsx')
## Change the Index column to Datetime
df = df.set_index('Datetime')

# %%
print(df)
# Out:
#                      PJMW_MW
# Datetime
# 2002-12-31 01:00:00     5077
# 2002-12-31 02:00:00     4939
# 2002-12-31 03:00:00     4885
# 2002-12-31 04:00:00     4857
# 2002-12-31 05:00:00     4930
# ...                      ...
# 2018-01-01 20:00:00     8401
# 2018-01-01 21:00:00     8373
# 2018-01-01 22:00:00     8238
# 2018-01-01 23:00:00     7958
# 2018-01-02 00:00:00     7691
#
# [143206 rows x 1 columns]

# %% [markdown]
# ## Plot Data using Matplotlib

# %%
df.plot(style='.', 
        figsize=(15,5), 
        color=color_pal[9], 
        title='PJMW Energy use in <W')
# Out:
# <AxesSubplot:title={'center':'PJMW Energy use in <W'}, xlabel='Datetime'>

# %%
# Convert Datetime Index to datetime
df.index = pd.to_datetime(df.index)

# %% [markdown]
# ## Train / Test Split Data

# %%
train = df.loc[df.index < '01-01-2015']
